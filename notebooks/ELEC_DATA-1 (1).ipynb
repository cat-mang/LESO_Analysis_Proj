# %%
#Import the packages I will use
import pandas as pd
import folium
from folium.plugins import FastMarkerCluster
from folium import IFrame
from pykml import parser
import csv
import webbrowser

# %%
#Browse data to look for certain key information to keep
filename = 'alt_fuel_stations (Jul 29 2021).csv'
df = pd.read_csv(filename, low_memory=False)
df
# Out:
#       Fuel Type Cotion Directions  \
# 0                             CNG
# 1                             CNG
# 2                             CNG
# 3                             CNG
# 4                             CNG
# ...                           ...
# 56795                         E85
# 56796                         E85
# 56797                         E85
# 56798                         E85
# 56799                         E85
#
#                                                     City  \
# 0                   Spire - Montgomery Operations Center
# 1                                    PS Energy - Atlanta
# 2           Metropolitan Atlanta Rapid Transit Authority
# 3                                  United Parcel Service
# 4      Clean Energy - Texas Department of Transportation
# ...                                                  ...
# 56795                                  Sheetz Store #713
# 56796                                    Kwik Trip #1062
# 56797                                                 76
# 56798                                Lafferty Race Fuels
# 56799                                    Kwik Star #1107
#
#                       State  \
# 0          2951 Chestnut St
# 1          340 Whitehall St
# 2       2424 Piedmont Rd NE
# 3      270 Marvin Miller Dr
# 4       7721A Washington St
# ...                     ...
# 56795   10515 Sharpsburg Pk
# 56796  1580 E Washington St
# 56797        675 N Lake Ave
# 56798       8800 S Osage St
# 56799      1900 16th Ave SW
#
#                                                      ZIP         Plus4  \
# 0                                                    NaN    Montgomery
# 1      From I-7585 N, exit 91 to Central Ave, left on...       Atlanta
# 2                                                    NaN       Atlanta
# 3                                                    NaN       Atlanta
# 4      I-10, Washington Ave exit, 1.5 blocks to the s...       Houston
# ...                                                  ...           ...
# 56795                                                NaN    Hagerstown
# 56796                                                NaN     West Bend
# 56797                                                NaN      Pasadena
# 56798                                                NaN      Amarillo
# 56799                                                NaN  Cedar Rapids
#
#       Station Phone Status Code  Expected Date Groups With Access Code  \
# 0                AL       36107            NaN                     NaN
# 1                GA       30303            NaN            770-350-3000
# 2                GA       30324            NaN                     NaN
# 3                GA       30336            NaN                     NaN
# 4                TX       77007            NaN            866-809-4869
# ...             ...         ...            ...                     ...
# 56795            MD       21740            NaN            240-513-7047
# 56796            WI       53095            NaN            262-334-0999
# 56797            CA       91101            NaN            626-578-1519
# 56798            TX       79118            NaN            806-674-7536
# 56799            IA       52404            NaN            319-362-3188
#
#       Access Days Time  ... Hydrogen Standards CNG Fill Type Code CNG PSI  \
# 0                    E  ...                NaN                NaN     NaN
# 1                    E  ...                NaN                NaN     NaN
# 2                    E  ...                NaN                NaN     NaN
# 3                    E  ...                NaN                NaN     NaN
# 4                    E  ...                NaN                NaN     NaN
# ...                ...  ...                ...                ...     ...
# 56795                E  ...                NaN                NaN     NaN
# 56796                E  ...                NaN                NaN     NaN
# 56797                E  ...                NaN                NaN     NaN
# 56798                E  ...                NaN                NaN     NaN
# 56799                E  ...                NaN                NaN     NaN
#
#       CNG Vehicle Class LNG Vehicle Class EV On-Site Renewable Source  \
# 0                   NaN                 B                        3600
# 1                   NaN                 Q                        3600
# 2                   NaN                 Q                        3000
# 3                   NaN                 B                        3600
# 4                   NaN                 Q                   3000 3600
# ...                 ...               ...                         ...
# 56795               NaN               NaN                         NaN
# 56796               NaN               NaN                         NaN
# 56797               NaN               NaN                         NaN
# 56798               NaN               NaN                         NaN
# 56799               NaN               NaN                         NaN
#
#       Restricted Accessde  Station Name  Street Address  Intersec
# 0                      MD           NaN             NaN       NaN
# 1                      MD           NaN             NaN       NaN
# 2                      LD           NaN             NaN       NaN
# 3                      HD           NaN             NaN       NaN
# 4                      MD           NaN             NaN       NaN
# ...                   ...           ...             ...       ...
# 56795                 NaN           NaN             NaN       NaN
# 56796                 NaN           NaN             NaN       NaN
# 56797                 NaN           NaN             NaN       NaN
# 56798                 NaN           NaN             NaN       NaN
# 56799                 NaN           NaN             NaN       NaN
#
# [56800 rows x 65 columns]

# %%
#Cleaning the Data
#Identify the columns to keep from original df
columns_to_keep = ['City', 'ID', 'Updated At','Fuel Type Cotion Directions', 'State']  

# Select only the specified columns
stations_df= df[columns_to_keep]
    
# Print the DataFrame with selected columns
stations_df.sample(15)
type(stations_df['City'])
type(stations_df['Updated At'])

# I need to remake new columns to make the DF easier to understand
stations_df['lat'] = stations_df['ID']
stations_df['lon'] = stations_df['Updated At']
stations_df['Address'] = stations_df['State']
stations_df['Station_Name'] = stations_df['City']
stations_df['Fuel Type'] = stations_df['Fuel Type Cotion Directions']
stations_df.head(10)
# Out:
# /var/folders/ly/6s9xls1s5k92nhwz4573k3vm0000gp/T/ipykernel_70533/2889185085.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df['lat'] = stations_df['ID']
# /var/folders/ly/6s9xls1s5k92nhwz4573k3vm0000gp/T/ipykernel_70533/2889185085.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df['lon'] = stations_df['Updated At']
# /var/folders/ly/6s9xls1s5k92nhwz4573k3vm0000gp/T/ipykernel_70533/2889185085.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df['Address'] = stations_df['State']
# /var/folders/ly/6s9xls1s5k92nhwz4573k3vm0000gp/T/ipykernel_70533/2889185085.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df['Station_Name'] = stations_df['City']
# /var/folders/ly/6s9xls1s5k92nhwz4573k3vm0000gp/T/ipykernel_70533/2889185085.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df['Fuel Type'] = stations_df['Fuel Type Cotion Directions']
#                                                 City         ID  Updated At  \
# 0               Spire - Montgomery Operations Center  32.367916  -86.267021
# 1                                PS Energy - Atlanta  33.745843  -84.398837
# 2       Metropolitan Atlanta Rapid Transit Authority  33.821911  -84.367461
# 3                              United Parcel Service  33.760256  -84.543822
# 4  Clean Energy - Texas Department of Transportation  29.779918  -95.435385
# 5                         Arkansas Oklahoma Gas Corp  35.362213  -94.375338
# 6         Clean Energy - Logan International Airport  42.374706  -71.026549
# 7             Clean Energy - Everett - National Grid  42.393167  -71.064352
# 8          Clean Energy - Greenpoint - National Grid  40.718037  -73.932309
# 9                           Canarsie - National Grid  40.645540  -73.918344
#
#   Fuel Type Cotion Directions                 State        lat        lon  \
# 0                         CNG      2951 Chestnut St  32.367916 -86.267021
# 1                         CNG      340 Whitehall St  33.745843 -84.398837
# 2                         CNG   2424 Piedmont Rd NE  33.821911 -84.367461
# 3                         CNG  270 Marvin Miller Dr  33.760256 -84.543822
# 4                         CNG   7721A Washington St  29.779918 -95.435385
# 5                         CNG     2100 S Waldron Rd  35.362213 -94.375338
# 6                         CNG   1000 Cottage St Ext  42.374706 -71.026549
# 7                         CNG           16 Rover St  42.393167 -71.064352
# 8                         CNG       287 Maspeth Ave  40.718037 -73.932309
# 9                         CNG       8424 Ditmas Ave  40.645540 -73.918344
#
#                 Address                                       Station_Name  \
# 0      2951 Chestnut St               Spire - Montgomery Operations Center
# 1      340 Whitehall St                                PS Energy - Atlanta
# 2   2424 Piedmont Rd NE       Metropolitan Atlanta Rapid Transit Authority
# 3  270 Marvin Miller Dr                              United Parcel Service
# 4   7721A Washington St  Clean Energy - Texas Department of Transportation
# 5     2100 S Waldron Rd                         Arkansas Oklahoma Gas Corp
# 6   1000 Cottage St Ext         Clean Energy - Logan International Airport
# 7           16 Rover St             Clean Energy - Everett - National Grid
# 8       287 Maspeth Ave          Clean Energy - Greenpoint - National Grid
# 9       8424 Ditmas Ave                           Canarsie - National Grid
#
#   Fuel Type
# 0       CNG
# 1       CNG
# 2       CNG
# 3       CNG
# 4       CNG
# 5       CNG
# 6       CNG
# 7       CNG
# 8       CNG
# 9       CNG

# %%
#renamed the columns to "lat" and "lon", dropped old columns

columns_to_drop = ['ID', 'Updated At','City', 'State', 'Fuel Type Cotion Directions']
stations_df.drop(columns=columns_to_drop, inplace=True)
ev_df = pd.DataFrame(stations_df)
# Out:
# /var/folders/ly/6s9xls1s5k92nhwz4573k3vm0000gp/T/ipykernel_70533/3868340838.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df.drop(columns=columns_to_drop, inplace=True)

# %%
#changed lat and lon to floats
ev_df['lat'] = ev_df['lat'].astype(float)
ev_df['lon'] = ev_df['lon'].astype(float)

#save the data as a new CSV
ev_df.to_csv('New_EV_Data.csv', index=False)

# %%
#creating a Test DataFrame to analyze the cleaned data
test_df =  ev_df.sample(1000)

# %%
#Create the map to host data on.

m = folium.Map(location=[test_df['lat'].mean(), test_df['lon'].mean()], zoom_start=4)

# Add markers for each location in the DataFrame
#USing the test_df for visualization purpose.
for index, row in test_df.iterrows():
    popup_text = f"<b>{row['Station_Name']}</b><br>Fuel Type: {row['Fuel Type']}<br>Address: {row['Address']}"
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=popup_text,
        tooltip=row['Station_Name']
    ).add_to(m)

# Save and open the map in a new window
# Save the map to an HTML file
m.save('map.html')

#Saves a local File of a Interactive map to analyze locations of
#Fuel Service Stations
webbrowser.open('map.html')

#Displays local map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07c6c9efdd052ede2c9088815d1a2bb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07c6c9efdd052ede2c9088815d1a2bb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07c6c9efdd052ede2c9088815d1a2bb6 = L.map(
#                 &quot;map_07c6c9efdd052ede2c9088815d1a2bb6&quot;,
#                 {
#                     center: [37.62503670517992, -99.12831153936536],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c67b838dddaf5d3d12b82ff14c20d19 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0c67b838dddaf5d3d12b82ff14c20d19.addTo(map_07c6c9efdd052ede2c9088815d1a2bb6);
#
#
#             var marker_b8ead53c73e72ac8a7759cdadd41b504 = L.marker(
#                 [33.512147, -86.816519],
#                 {}
#             ).addTo(map_07c6c9efdd052ede2c9088815d1a2bb6);
#
#
#         var popup_09dc8162e1ccc3667416d4a1045d6904 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa7181a4c4752926b9ae4831d67e7c04 = $(`&lt;div id=&quot;html_aa7181a4c4752926b9ae4831d67e7c04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Jim Burke Nissan&lt;/b&gt;&lt;br&gt;Fuel Type: ELEC&lt;br&gt;Address: 1300 3rd Ave N&lt;/div&gt;`)[0];
#                 popup_09dc8162e1ccc3667416d4a1045d6904.setContent(html_aa7181a4c4752926b9ae4831d67e7c04);
#
#
#
#         marker_b8ead53c73e72ac8a7759cdadd41b504.bindPopup(popup_09dc8162e1ccc3667416d4a1045d6904)
#         ;
#
#
#
#
#             marker_b8ead53c73e72ac8a7759cdadd41b504.bindTooltip(
#                 `&lt;div&gt;
#                      Jim Burke Nissan
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_94b97beb638548329ce479f8a835243b = L.marker(
#                 [44.954293, -92.987797],
#                 {}
#             ).addTo(map_07c6c9efdd052ede2c9088815d1a2bb6);
#
#
#         var popup_2f7e541c545f53551d9844bc81e97bb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d4435a292f10785cdc016019ccc4517 = $(`&lt;div id=&quot;html_8d4435a292f10785cdc016019ccc4517&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;3M 236 STATION #3&lt;/b&gt;&lt;br&gt;Fuel Type: ELEC&lt;br&gt;Address: 240 Avenue K&lt;/div&gt;`)[0];
#                 popup_2f7e541c545f53551d9844bc81e97bb4.setContent(html_8d4435a292f10785cdc016019ccc4517);
#
#
#
#         marker_94b97beb638548329ce479f8a835243b.bindPopup(popup_2f7e541c545f53551d9844bc81e97bb4)
#         ;
#
#
#
#
#             marker_94b97beb638548329ce479f8a835243b.bindTooltip(
#                 `&lt;div&gt;
#                      3M 236 STATION #3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a5d7847d1bdd0d6f4f11527f97b42122 = L.marker(
#                 [37.324285, -122.009148],
#                 {}
#             ).addTo(map_07c6c9efdd052ede2c9088815d1a2bb6);
#
#
#         var popup_cd4a3982013f413a45be2e4e5402235a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b6d7f265791bb611126cddcd9371f9d = $(`&lt;div id=&quot;html_6b6d7f265791bb611126cddcd9371f9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;MAIN STREET MSC 11&lt;/b&gt;&lt;br&gt;Fuel Type: ELEC&lt;br&gt;Address: 19500 Stevens Creek Blvd&lt;/div&gt;`)[0];
#                 popup_cd4a3982013f413a45be2e4e5402235a.setContent(html_6b6d7f265791bb611126cddcd9371f9d);
#
#
#
#         marker_a5d7847d1bdd0d6f4f11527f97b42122.bindPopup(popup_cd4a3982013f413a45be2e4e5402235a)
#         ;
#
#
#
#
#             marker_a5d7847d1bdd0d6f4f11527f97b42122.bindTooltip(
#                 `&lt;div&gt;
#                      MAIN STREET MSC 11
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_600fcf150c3c94ff3d9ff651718a37cf = L.marker(
#                 [37.1581, -80.4203],
#                 {}
#             ).addTo(map_07c6c9efdd052ede2c9088815d1a2bb6);
#
#
#         var popup_2c4edf749aa571c71edc01fd1099cbb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af90a3c9fafd9c5e01006ce2997527ad = $(`&lt;div id=&quot;html_af90a3c9fafd9c5e01006ce2997527ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;New River Nissan&lt;/b&gt;&lt;br&gt;Fuel Type: ELEC&lt;br&gt;Address: 2130 N Franklin St&lt;/div&gt;`)[0];
#                 popup_2c4edf749aa571c71edc01fd1099cbb8.setContent(html_af90a3c9fafd9c5e01006ce2997527ad);
#
#
#
#         marker_600fcf150c3c94ff3d9ff651718a37cf.b
